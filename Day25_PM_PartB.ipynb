# %% [markdown]
# <a href="https://colab.research.google.com/github/hiten4/Day25PM/blob/main/Day25_PM_PartB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 25 PM — Part B

# %%
# regression example
X_reg = [1,2,3,4,5]
y_reg = [2,4,6,8,10]

# classification example
X_clf = [1,2,3,4,5]
y_clf = [0,0,1,1,1]

X_reg, y_reg, X_clf, y_clf
# Out:
# ([1, 2, 3, 4, 5], [2, 4, 6, 8, 10], [1, 2, 3, 4, 5], [0, 0, 1, 1, 1])
